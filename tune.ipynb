# %%
from ultralytics import YOLO
import torch

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# Initialize the YOLO model
model = YOLO('yolov8m.pt').to(device)

# %%
# Tune hyperparameters on COCO8 for 30 epochs
# 86 min per epochs=30, iterations=50
model.tune(data='data.yaml', epochs=30, iterations=50, optimizer='AdamW', imgsz=[1120, 840])  # plots=False, save=False, val=False
# Out:
# Tuner: Initialized Tuner instance with 'tune_dir=runs/detect/tune'
# Tuner: 💡 Learn about tuning at https://docs.ultralytics.com/guides/hyperparameter-tuning
# Tuner: Starting iteration 1/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# New https://pypi.org/project/ultralytics/8.2.58 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.39 🚀 Python-3.11.7 torch-2.5.0.dev20240621 CUDA:0 (NVIDIA GeForce RTX 4090, 24214MiB)
# engine/trainer: task=detect, mode=train, model=yolov8m.pt, data=data.yaml, epochs=30, time=None, patience=100, batch=16, imgsz=[1120, 840], save=False, save_period=-1, cache=False, device=cuda:0, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=AdamW, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=False, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=False, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776854  ultralytics.nn.modules.head.Detect           [2, [192, 384, 576]]
# Model summary: 295 layers, 25857478 parameters, 25857462 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# wandb: Currently logged in as: kekwak. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.17.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.17.2
# wandb: Run data is saved locally in /home/kekwak/Рабочий стол/НИИ/yolo/wandb/run-20240716_172357-r8h0ykyx
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run train
# wandb: ⭐️ View project at https://wandb.ai/kekwak/YOLOv8
# wandb: 🚀 View run at https://wandb.ai/kekwak/YOLOv8/runs/r8h0ykyx
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# /home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/utils/checks.py:651: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(True):
# AMP: checks passed ✅
# WARNING ⚠️ updating to 'imgsz=1120'. 'train' and 'val' imgsz must be an integer, while 'predict' and 'export' imgsz may be a [h, w] list or an integer, i.e. 'yolo export imgsz=640,480' or 'yolo export imgsz=640'
# train: WARNING ⚠️ /home/kekwak/Рабочий стол/НИИ/yolo/basil-4/train/images/PS-V2ver-L6-sch36_jpg.rf.7ce50ffad08f16a20c57705311ee700b.jpg: 1 duplicate labels removed
# /home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:262: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.amp)
# train: Scanning /home/kekwak/Рабочий стол/НИИ/yolo/basil-4/train/labels.cache... 80 images, 0 backgrounds, 0 corrupt: 100%|██████████| 80/80 [00:00<?, ?it/s]
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.11 (you have 1.4.10). Upgrade using: pip install --upgrade albumentations
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /home/kekwak/Рабочий стол/НИИ/yolo/basil-4/valid/labels.cache... 15 images, 0 backgrounds, 0 corrupt: 100%|██████████| 15/15 [00:00<?, ?it/s]
# optimizer: AdamW(lr=0.01, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 1120 train, 1120 val
# Using 8 dataloader workers
# Logging results to runs/detect/train
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        1/30      22.2G      1.613       3.72      1.068        709       1120: 100%|██████████| 5/5 [00:04<00:00,  1.06it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        2/30      19.2G      1.718      12.08      1.112        566       1120: 100%|██████████| 5/5 [00:02<00:00,  2.22it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        3/30      21.1G      1.952      11.07        1.2        594       1120: 100%|██████████| 5/5 [00:02<00:00,  2.23it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        4/30      21.4G      1.462      2.368      1.083        711       1120: 100%|██████████| 5/5 [00:02<00:00,  2.31it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        5/30      19.8G      1.461      2.153      1.024        796       1120: 100%|██████████| 5/5 [00:02<00:00,  2.33it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        6/30      21.6G      1.345      1.769     0.9939        779       1120: 100%|██████████| 5/5 [00:02<00:00,  2.28it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        7/30      20.6G      1.355      1.658      1.032       1055       1120: 100%|██████████| 5/5 [00:02<00:00,  2.31it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        8/30      20.1G      1.277      1.512      1.005        798       1120: 100%|██████████| 5/5 [00:02<00:00,  2.31it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        9/30      20.2G      1.192      1.417     0.9692        590       1120: 100%|██████████| 5/5 [00:02<00:00,  2.32it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       10/30      22.2G      1.205      1.359     0.9459        757       1120: 100%|██████████| 5/5 [00:02<00:00,  2.26it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       11/30      21.8G      1.116      1.316     0.9476        665       1120: 100%|██████████| 5/5 [00:02<00:00,  2.33it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       12/30        20G      1.099      1.288     0.9529        532       1120: 100%|██████████| 5/5 [00:02<00:00,  2.38it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       13/30      21.6G        1.1      1.256     0.9389        813       1120: 100%|██████████| 5/5 [00:02<00:00,  2.34it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       14/30      20.7G      1.067       1.19     0.9277        680       1120: 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       15/30      20.8G      1.112      1.223     0.9358        553       1120: 100%|██████████| 5/5 [00:02<00:00,  2.35it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       16/30      22.1G       1.07      1.221     0.9386        676       1120: 100%|██████████| 5/5 [00:02<00:00,  2.37it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       17/30      22.3G       1.07      1.157     0.9296        817       1120: 100%|██████████| 5/5 [00:02<00:00,  2.30it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       18/30      20.7G      1.013      1.159     0.9332        685       1120: 100%|██████████| 5/5 [00:02<00:00,  2.34it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       19/30      20.8G      1.018      1.131     0.9149        964       1120: 100%|██████████| 5/5 [00:02<00:00,  2.35it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       20/30      19.7G      1.023      1.148     0.9264        608       1120: 100%|██████████| 5/5 [00:02<00:00,  2.34it/s]
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       21/30      20.2G     0.9907       1.17      0.924        351       1120: 100%|██████████| 5/5 [00:02<00:00,  1.77it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       22/30      19.8G     0.9287      1.085     0.9069        379       1120: 100%|██████████| 5/5 [00:02<00:00,  2.45it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       23/30      20.1G     0.9386      1.094     0.9118        422       1120: 100%|██████████| 5/5 [00:02<00:00,  2.43it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       24/30      20.1G     0.9206      1.075     0.9074        394       1120: 100%|██████████| 5/5 [00:02<00:00,  2.39it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       25/30      21.2G     0.9612       1.06     0.9125        477       1120: 100%|██████████| 5/5 [00:02<00:00,  2.39it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       26/30      20.9G      0.921      1.047     0.9076        419       1120: 100%|██████████| 5/5 [00:02<00:00,  2.42it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       27/30      20.8G     0.9206      1.022     0.9194        433       1120: 100%|██████████| 5/5 [00:02<00:00,  2.44it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       28/30      20.2G     0.8903      1.005     0.9011        351       1120: 100%|██████████| 5/5 [00:02<00:00,  2.42it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       29/30      20.1G     0.8751     0.9868     0.8966        401       1120: 100%|██████████| 5/5 [00:02<00:00,  2.39it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       30/30      19.7G     0.8817     0.9842     0.9044        292       1120: 100%|██████████| 5/5 [00:02<00:00,  2.44it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.51it/s]
#                    all         15        357      0.659      0.774      0.786      0.623
#
# 30 epochs completed in 0.021 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 52.1MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 52.1MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.39 🚀 Python-3.11.7 torch-2.5.0.dev20240621 CUDA:0 (NVIDIA GeForce RTX 4090, 24214MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#                    all         15        357      0.659      0.775      0.786      0.624
#                  Empty         14        143      0.653      0.699      0.722      0.544
#                   Full         15        214      0.665       0.85      0.851      0.703
# Speed: 0.3ms preprocess, 4.5ms inference, 0.0ms loss, 0.7ms postprocess per image
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  9.45it/s]
# /home/kekwak/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/kekwak/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Traceback (most recent call last):
#   File "/home/kekwak/anaconda3/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/cfg/__init__.py", line 591, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/model.py", line 673, in train
#     self.trainer.train()
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 199, in train
#     self._do_train(world_size)
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 467, in _do_train
#     self.run_callbacks("on_train_end")
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 162, in run_callbacks
#     callback(self)
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/utils/callbacks/wb.py", line 142, in on_train_end
#     _plot_curve(
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/utils/callbacks/wb.py", line 87, in _plot_curve
#     y_log = np.interp(x_new, x, np.mean(y, axis=0)).round(3).tolist()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py", line 1599, in interp
#     return interp_func(x, xp, fp, left, right)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: object of too small depth for desired array
# Traceback (most recent call last):
#   File "/home/kekwak/anaconda3/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/cfg/__init__.py", line 591, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/model.py", line 673, in train
#     self.trainer.train()
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 199, in train
#     self._do_train(world_size)
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 467, in _do_train
#     self.run_callbacks("on_train_end")
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 162, in run_callbacks
#     callback(self)
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/utils/callbacks/wb.py", line 142, in on_train_end
#     _plot_curve(
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/utils/callbacks/wb.py", line 87, in _plot_curve
#     y_log = np.interp(x_new, x, np.mean(y, axis=0)).round(3).tolist()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py", line 1599, in interp
#     return interp_func(x, xp, fp, left, right)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: object of too small depth for desired array
# wandb: - 49.744 MB of 49.744 MB uploaded
# wandb: Run history:
# wandb:                  lr/pg0 ██▇▇▇▆▆▆▅▅▅▄▄▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  lr/pg1 ▁▂▃▄▄▅▆▆▇▇▇████████▇▇▆▆▅▄▄▃▂▂▁
# wandb:                  lr/pg2 ▁▂▃▄▄▅▆▆▇▇▇████████▇▇▆▆▅▄▄▃▂▂▁
# wandb:        metrics/mAP50(B) ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:     metrics/mAP50-95(B) ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:    metrics/precision(B) ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:       metrics/recall(B) ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:            model/GFLOPs ▁
# wandb:        model/parameters ▁
# wandb: model/speed_PyTorch(ms) ▁
# wandb:          train/box_loss ▆▆█▅▅▄▄▄▃▃▃▂▂▂▃▂▂▂▂▂▂▁▁▁▂▁▁▁▁▁
# wandb:          train/cls_loss ▃█▇▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          train/dfl_loss ▅▆█▅▄▃▄▄▃▂▂▂▂▂▂▂▂▂▁▂▂▁▁▁▁▁▂▁▁▁
# wandb:            val/box_loss ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:            val/cls_loss ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:            val/dfl_loss ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:
# wandb: Run summary:
# wandb:                  lr/pg0 0.00043
# wandb:                  lr/pg1 0.00043
# wandb:                  lr/pg2 0.00043
# wandb:        metrics/mAP50(B) 0.78646
# wandb:     metrics/mAP50-95(B) 0.62355
# wandb:    metrics/precision(B) 0.65897
# wandb:       metrics/recall(B) 0.77458
# wandb:            model/GFLOPs 79.069
# wandb:        model/parameters 25857478
# wandb: model/speed_PyTorch(ms) 0.0
# wandb:          train/box_loss 0.88174
# wandb:          train/cls_loss 0.98424
# wandb:          train/dfl_loss 0.90443
# wandb:            val/box_loss 0.7611
# wandb:            val/cls_loss 0.83794
# wandb:            val/dfl_loss 0.84207
# wandb:
# wandb: 🚀 View run train at: https://wandb.ai/kekwak/YOLOv8/runs/r8h0ykyx
# wandb: ⭐️ View project at: https://wandb.ai/kekwak/YOLOv8
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240716_172357-r8h0ykyx/logs
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# WARNING ❌️ training failure for hyperparameter tuning iteration 1
# Command '['yolo', 'train', 'task=detect', 'mode=train', 'model=yolov8m.pt', 'data=data.yaml', 'epochs=30', 'time=None', 'patience=100', 'batch=16', 'imgsz=[1120, 840]', 'save=False', 'save_period=-1', 'cache=False', 'device=cuda:0', 'workers=8', 'project=None', 'name=None', 'exist_ok=False', 'pretrained=True', 'optimizer=AdamW', 'verbose=True', 'seed=0', 'deterministic=True', 'single_cls=False', 'rect=False', 'cos_lr=False', 'close_mosaic=10', 'resume=False', 'amp=True', 'fraction=1.0', 'profile=False', 'freeze=None', 'multi_scale=False', 'overlap_mask=True', 'mask_ratio=4', 'dropout=0.0', 'val=False', 'split=val', 'save_json=False', 'save_hybrid=False', 'conf=None', 'iou=0.7', 'max_det=300', 'half=False', 'dnn=False', 'plots=False', 'source=None', 'vid_stride=1', 'stream_buffer=False', 'visualize=False', 'augment=False', 'agnostic_nms=False', 'classes=None', 'retina_masks=False', 'embed=None', 'show=False', 'save_frames=False', 'save_txt=False', 'save_conf=False', 'save_crop=False', 'show_labels=True', 'show_conf=True', 'show_boxes=True', 'line_width=None', 'format=torchscript', 'keras=False', 'optimize=False', 'int8=False', 'dynamic=False', 'simplify=False', 'opset=None', 'workspace=4', 'nms=False', 'lr0=0.01', 'lrf=0.01', 'momentum=0.937', 'weight_decay=0.0005', 'warmup_epochs=3.0', 'warmup_momentum=0.8', 'warmup_bias_lr=0.1', 'box=7.5', 'cls=0.5', 'dfl=1.5', 'pose=12.0', 'kobj=1.0', 'label_smoothing=0.0', 'nbs=64', 'hsv_h=0.015', 'hsv_s=0.7', 'hsv_v=0.4', 'degrees=0.0', 'translate=0.1', 'scale=0.5', 'shear=0.0', 'perspective=0.0', 'flipud=0.0', 'fliplr=0.5', 'bgr=0.0', 'mosaic=1.0', 'mixup=0.0', 'copy_paste=0.0', 'auto_augment=randaugment', 'erasing=0.4', 'crop_fraction=1.0', 'cfg=None', 'tracker=botsort.yaml']' returned non-zero exit status 1.
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 1/50 iterations complete ✅ (108.14s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.0 observed at iteration 1
# Tuner: Best fitness metrics are {}
# Tuner: Best fitness model is runs/detect/train
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
#
# Tuner: Starting iteration 2/50 with hyperparameters: {'lr0': 0.01, 'lrf': 0.00958, 'momentum': 0.94529, 'weight_decay': 0.00048, 'warmup_epochs': 3.20926, 'warmup_momentum': 0.77821, 'box': 7.5, 'cls': 0.44578, 'dfl': 1.56293, 'hsv_h': 0.01555, 'hsv_s': 0.69396, 'hsv_v': 0.39323, 'degrees': 0.0, 'translate': 0.10616, 'scale': 0.56492, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.48377, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0}
# New https://pypi.org/project/ultralytics/8.2.58 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.39 🚀 Python-3.11.7 torch-2.5.0.dev20240621 CUDA:0 (NVIDIA GeForce RTX 4090, 24214MiB)
# engine/trainer: task=detect, mode=train, model=yolov8m.pt, data=data.yaml, epochs=30, time=None, patience=100, batch=16, imgsz=[1120, 840], save=False, save_period=-1, cache=False, device=cuda:0, workers=8, project=None, name=train2, exist_ok=False, pretrained=True, optimizer=AdamW, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=False, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=False, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.00958, momentum=0.94529, weight_decay=0.00048, warmup_epochs=3.20926, warmup_momentum=0.77821, warmup_bias_lr=0.1, box=7.5, cls=0.44578, dfl=1.56293, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.01555, hsv_s=0.69396, hsv_v=0.39323, degrees=0.0, translate=0.10616, scale=0.56492, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.48377, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train2
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776854  ultralytics.nn.modules.head.Detect           [2, [192, 384, 576]]
# Model summary: 295 layers, 25857478 parameters, 25857462 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# wandb: Currently logged in as: kekwak. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.17.4 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.17.2
# wandb: Run data is saved locally in /home/kekwak/Рабочий стол/НИИ/yolo/wandb/run-20240716_172546-bbxmznls
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run train2
# wandb: ⭐️ View project at https://wandb.ai/kekwak/YOLOv8
# wandb: 🚀 View run at https://wandb.ai/kekwak/YOLOv8/runs/bbxmznls
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# /home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/utils/checks.py:651: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(True):
# AMP: checks passed ✅
# WARNING ⚠️ updating to 'imgsz=1120'. 'train' and 'val' imgsz must be an integer, while 'predict' and 'export' imgsz may be a [h, w] list or an integer, i.e. 'yolo export imgsz=640,480' or 'yolo export imgsz=640'
# train: WARNING ⚠️ /home/kekwak/Рабочий стол/НИИ/yolo/basil-4/train/images/PS-V2ver-L6-sch36_jpg.rf.7ce50ffad08f16a20c57705311ee700b.jpg: 1 duplicate labels removed
# /home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:262: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=self.amp)
# train: Scanning /home/kekwak/Рабочий стол/НИИ/yolo/basil-4/train/labels.cache... 80 images, 0 backgrounds, 0 corrupt: 100%|██████████| 80/80 [00:00<?, ?it/s]
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.11 (you have 1.4.10). Upgrade using: pip install --upgrade albumentations
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /home/kekwak/Рабочий стол/НИИ/yolo/basil-4/valid/labels.cache... 15 images, 0 backgrounds, 0 corrupt: 100%|██████████| 15/15 [00:00<?, ?it/s]
# optimizer: AdamW(lr=0.01, momentum=0.94529) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.00048), 83 bias(decay=0.0)
# Image sizes 1120 train, 1120 val
# Using 8 dataloader workers
# Logging results to runs/detect/train2
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        1/30      22.6G      1.623      3.336      1.111        727       1120: 100%|██████████| 5/5 [00:04<00:00,  1.01it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        2/30      19.5G      1.675      11.64      1.129        578       1120: 100%|██████████| 5/5 [00:02<00:00,  2.21it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        3/30      21.1G        1.8       10.5      1.179        603       1120: 100%|██████████| 5/5 [00:02<00:00,  2.22it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        4/30      21.5G      1.496      2.465       1.18        702       1120: 100%|██████████| 5/5 [00:02<00:00,  2.30it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        5/30      19.8G       1.47      1.906      1.115        824       1120: 100%|██████████| 5/5 [00:02<00:00,  2.30it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        6/30      21.7G      1.346      1.476      1.028        814       1120: 100%|██████████| 5/5 [00:02<00:00,  2.30it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        7/30      21.5G       1.32      1.541      1.047       1087       1120: 100%|██████████| 5/5 [00:02<00:00,  2.32it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        8/30      20.3G      1.194      1.399      1.013        822       1120: 100%|██████████| 5/5 [00:02<00:00,  2.31it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#        9/30      20.3G      1.195      1.269       1.01        619       1120: 100%|██████████| 5/5 [00:02<00:00,  2.32it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       10/30      21.1G        1.2      1.243     0.9866        801       1120: 100%|██████████| 5/5 [00:02<00:00,  2.27it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       11/30        22G      1.125      1.279     0.9808        681       1120: 100%|██████████| 5/5 [00:02<00:00,  2.32it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       12/30      20.1G      1.154      1.237          1        542       1120: 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       13/30      21.8G      1.112      1.191     0.9771        853       1120: 100%|██████████| 5/5 [00:02<00:00,  2.32it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       14/30      20.9G       1.05      1.096     0.9644        687       1120: 100%|██████████| 5/5 [00:02<00:00,  2.32it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       15/30      20.9G      1.116      1.128     0.9696        576       1120: 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       16/30      22.2G      1.082      1.139     0.9933        695       1120: 100%|██████████| 5/5 [00:02<00:00,  2.36it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       17/30      22.5G      1.059       1.08      0.963        845       1120: 100%|██████████| 5/5 [00:02<00:00,  2.32it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# ...
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       18/30      19.3G      1.025      1.135     0.8096        545       1120: 100%|██████████| 5/5 [00:01<00:00,  2.57it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       19/30      19.9G     0.9901        1.1     0.8057        574       1120: 100%|██████████| 5/5 [00:01<00:00,  2.61it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       20/30      19.7G      1.002      1.102     0.8027        654       1120: 100%|██████████| 5/5 [00:01<00:00,  2.52it/s]
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       21/30      20.2G     0.9389      1.084      0.794        357       1120: 100%|██████████| 5/5 [00:02<00:00,  1.85it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       22/30      19.8G     0.9283      1.055     0.7848        384       1120: 100%|██████████| 5/5 [00:01<00:00,  2.59it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       23/30        20G     0.9432      1.033     0.7869        433       1120: 100%|██████████| 5/5 [00:01<00:00,  2.57it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       24/30      19.5G     0.9222      1.029     0.7848        398       1120: 100%|██████████| 5/5 [00:01<00:00,  2.55it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       25/30      21.2G     0.9433      1.035     0.7895        479       1120: 100%|██████████| 5/5 [00:01<00:00,  2.55it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       26/30      20.9G     0.9038      1.022     0.7849        420       1120: 100%|██████████| 5/5 [00:01<00:00,  2.57it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       27/30      20.8G      0.913      1.016     0.7924        442       1120: 100%|██████████| 5/5 [00:01<00:00,  2.59it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       28/30      20.2G     0.8974      1.004     0.7855        361       1120: 100%|██████████| 5/5 [00:01<00:00,  2.55it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       29/30      20.8G     0.8696      0.979     0.7794        409       1120: 100%|██████████| 5/5 [00:01<00:00,  2.55it/s]
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/5 [00:00<?, ?it/s]/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py:374: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(self.amp):
#       30/30      19.7G     0.8788     0.9729     0.7879        303       1120: 100%|██████████| 5/5 [00:01<00:00,  2.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  7.48it/s]
#                    all         15        357      0.585      0.777      0.731      0.583
#
# 30 epochs completed in 0.020 hours.
# Optimizer stripped from runs/detect/train50/weights/last.pt, 52.1MB
# Optimizer stripped from runs/detect/train50/weights/best.pt, 52.1MB
#
# Validating runs/detect/train50/weights/best.pt...
# Ultralytics YOLOv8.2.39 🚀 Python-3.11.7 torch-2.5.0.dev20240621 CUDA:0 (NVIDIA GeForce RTX 4090, 24214MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#                    all         15        357      0.583      0.777       0.73      0.583
#                  Empty         14        143      0.594      0.671      0.633      0.475
#                   Full         15        214      0.572      0.883      0.827       0.69
# Speed: 0.3ms preprocess, 4.0ms inference, 0.0ms loss, 0.7ms postprocess per image
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00, 10.18it/s]
# /home/kekwak/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/kekwak/anaconda3/lib/python3.11/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Traceback (most recent call last):
#   File "/home/kekwak/anaconda3/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/cfg/__init__.py", line 591, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/model.py", line 673, in train
#     self.trainer.train()
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 199, in train
#     self._do_train(world_size)
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 467, in _do_train
#     self.run_callbacks("on_train_end")
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 162, in run_callbacks
#     callback(self)
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/utils/callbacks/wb.py", line 142, in on_train_end
#     _plot_curve(
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/utils/callbacks/wb.py", line 87, in _plot_curve
#     y_log = np.interp(x_new, x, np.mean(y, axis=0)).round(3).tolist()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py", line 1599, in interp
#     return interp_func(x, xp, fp, left, right)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: object of too small depth for desired array
# Traceback (most recent call last):
#   File "/home/kekwak/anaconda3/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/cfg/__init__.py", line 591, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/model.py", line 673, in train
#     self.trainer.train()
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 199, in train
#     self._do_train(world_size)
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 467, in _do_train
#     self.run_callbacks("on_train_end")
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/engine/trainer.py", line 162, in run_callbacks
#     callback(self)
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/utils/callbacks/wb.py", line 142, in on_train_end
#     _plot_curve(
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/ultralytics/utils/callbacks/wb.py", line 87, in _plot_curve
#     y_log = np.interp(x_new, x, np.mean(y, axis=0)).round(3).tolist()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/kekwak/anaconda3/lib/python3.11/site-packages/numpy/lib/function_base.py", line 1599, in interp
#     return interp_func(x, xp, fp, left, right)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: object of too small depth for desired array
# wandb: / 49.744 MB of 49.744 MB uploaded
# wandb: Run history:
# wandb:                  lr/pg0 ██▇▇▇▆▆▆▅▅▅▄▄▄▃▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁
# wandb:                  lr/pg1 ▁▂▃▄▄▅▆▆▇▇▇████████▇▇▆▆▅▄▄▃▂▂▁
# wandb:                  lr/pg2 ▁▂▃▄▄▅▆▆▇▇▇████████▇▇▆▆▅▄▄▃▂▂▁
# wandb:        metrics/mAP50(B) ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:     metrics/mAP50-95(B) ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:    metrics/precision(B) ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:       metrics/recall(B) ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:            model/GFLOPs ▁
# wandb:        model/parameters ▁
# wandb: model/speed_PyTorch(ms) ▁
# wandb:          train/box_loss ▇▇█▆▅▅▅▅▄▃▃▃▃▃▃▃▂▂▂▂▂▁▂▁▂▁▁▁▁▁
# wandb:          train/cls_loss ▃▆█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:          train/dfl_loss ▇▇█▇▆▅▅▆▄▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁
# wandb:            val/box_loss ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:            val/cls_loss ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:            val/dfl_loss ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█
# wandb:
# wandb: Run summary:
# wandb:                  lr/pg0 0.00049
# wandb:                  lr/pg1 0.00049
# wandb:                  lr/pg2 0.00049
# wandb:        metrics/mAP50(B) 0.7305
# wandb:     metrics/mAP50-95(B) 0.58261
# wandb:    metrics/precision(B) 0.58285
# wandb:       metrics/recall(B) 0.77725
# wandb:            model/GFLOPs 79.069
# wandb:        model/parameters 25857478
# wandb: model/speed_PyTorch(ms) 0.0
# wandb:          train/box_loss 0.87875
# wandb:          train/cls_loss 0.97286
# wandb:          train/dfl_loss 0.78786
# wandb:            val/box_loss 0.74362
# wandb:            val/cls_loss 0.85285
# wandb:            val/dfl_loss 0.73191
# wandb:
# wandb: 🚀 View run train50 at: https://wandb.ai/kekwak/YOLOv8/runs/rsj2p7kx
# wandb: ⭐️ View project at: https://wandb.ai/kekwak/YOLOv8
# wandb: Synced 6 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240716_184834-rsj2p7kx/logs
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.
# WARNING ❌️ training failure for hyperparameter tuning iteration 50
# Command '['yolo', 'train', 'task=detect', 'mode=train', 'model=yolov8m.pt', 'data=data.yaml', 'epochs=30', 'time=None', 'patience=100', 'batch=16', 'imgsz=[1120, 840]', 'save=False', 'save_period=-1', 'cache=False', 'device=cuda:0', 'workers=8', 'project=None', 'name=None', 'exist_ok=False', 'pretrained=True', 'optimizer=AdamW', 'verbose=True', 'seed=0', 'deterministic=True', 'single_cls=False', 'rect=False', 'cos_lr=False', 'close_mosaic=10', 'resume=False', 'amp=True', 'fraction=1.0', 'profile=False', 'freeze=None', 'multi_scale=False', 'overlap_mask=True', 'mask_ratio=4', 'dropout=0.0', 'val=False', 'split=val', 'save_json=False', 'save_hybrid=False', 'conf=None', 'iou=0.7', 'max_det=300', 'half=False', 'dnn=False', 'plots=False', 'source=None', 'vid_stride=1', 'stream_buffer=False', 'visualize=False', 'augment=False', 'agnostic_nms=False', 'classes=None', 'retina_masks=False', 'embed=None', 'show=False', 'save_frames=False', 'save_txt=False', 'save_conf=False', 'save_crop=False', 'show_labels=True', 'show_conf=True', 'show_boxes=True', 'line_width=None', 'format=torchscript', 'keras=False', 'optimize=False', 'int8=False', 'dynamic=False', 'simplify=False', 'opset=None', 'workspace=4', 'nms=False', 'lr0=0.01094', 'lrf=0.01153', 'momentum=0.92925', 'weight_decay=0.00056', 'warmup_epochs=3.48881', 'warmup_momentum=0.59726', 'warmup_bias_lr=0.1', 'box=7.58089', 'cls=0.47962', 'dfl=1.31', 'pose=12.0', 'kobj=1.0', 'label_smoothing=0.0', 'nbs=64', 'hsv_h=0.01688', 'hsv_s=0.661', 'hsv_v=0.74555', 'degrees=0.0', 'translate=0.10758', 'scale=0.40848', 'shear=0.0', 'perspective=0.0', 'flipud=0.0', 'fliplr=0.49847', 'bgr=0.0', 'mosaic=0.67999', 'mixup=0.0', 'copy_paste=0.0', 'auto_augment=randaugment', 'erasing=0.4', 'crop_fraction=1.0', 'cfg=None', 'tracker=botsort.yaml']' returned non-zero exit status 1.
# Saved runs/detect/tune/tune_scatter_plots.png
# Saved runs/detect/tune/tune_fitness.png
#
# Tuner: 50/50 iterations complete ✅ (5178.00s)
# Tuner: Results saved to runs/detect/tune
# Tuner: Best fitness=0.0 observed at iteration 1
# Tuner: Best fitness metrics are {}
# Tuner: Best fitness model is runs/detect/train
# Tuner: Best fitness hyperparameters are printed below.
#
# Printing 'runs/detect/tune/best_hyperparameters.yaml'
#
# lr0: 0.01
# lrf: 0.01
# momentum: 0.937
# weight_decay: 0.0005
# warmup_epochs: 3.0
# warmup_momentum: 0.8
# box: 7.5
# cls: 0.5
# dfl: 1.5
# hsv_h: 0.015
# hsv_s: 0.7
# hsv_v: 0.4
# degrees: 0.0
# translate: 0.1
# scale: 0.5
# shear: 0.0
# perspective: 0.0
# flipud: 0.0
# fliplr: 0.5
# bgr: 0.0
# mosaic: 1.0
# mixup: 0.0
# copy_paste: 0.0
